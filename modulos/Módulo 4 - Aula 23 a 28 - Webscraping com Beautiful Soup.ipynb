# %% [markdown]
# # Módulo 4 - Webscraping com Beautiful Soup

# %% [markdown]
# # aula 23

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.body
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>

# %%
soup.head
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
soup.body.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.find_all('p','title')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>]

# %% [markdown]
# # aula 24

# %%
import requests
import pandas as pd
from datetime import datetime
from bs4 import BeautifulSoup
import numpy as np

# %%
url = 'https://www2.hm.com/en_us/men/products/jeans.html'

# %%
#para fazer requisição na API para puxar os dados html
#headers é um dicionário que vai dizer pra API da H&M que quem está fazendo a requisição
#é um browser e não um código python; é padrão

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
           
page = requests.get(url, headers=headers)

# %%
page.text
# Out:
# '<!DOCTYPE HTML>\n<html lang="en-US" is-in-aem="false" class="no-js en-us" ng-app="hmApp" >\n    \n\n\n    <head>\r\n    \r\n  <link rel="dns-prefetch" href="https://s1-cdn.hm.com"/>\r\n  <link rel="preconnect" href="https://s1-cdn.hm.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://tags.tiqcdn.com"/>\r\n  <link rel="preconnect" href="https://tags.tiqcdn.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://lp2.hm.com"/>\r\n  <link rel="preconnect" href="https://lp2.hm.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://cdn-pci.optimizely.com"/>\r\n  <link rel="preconnect" href="https://cdn-pci.optimizely.com" crossorigin/>\r\n\r\n  <link rel="dns-prefetch" href="https://s.go-mpulse.net"/>\r\n  <link rel="preconnect" href="https://s.go-mpulse.net" crossorigin/>\r\n\n\t\n\t\t<script type="text/javascript" src="https://cdn.cookielaw.org/consent/511a7faf-cc2d-4b69-86fb-a37761829422/OtAutoBlock.js"></script>\n\t\t<script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" data-document-language="true" type="text/javascript" charset="UTF-8" data-domain-script="511a7faf-cc2d-4b69-86fb-a37761829422"></script>\n    \t\n    \t\t<script type="text/javascript">function OptanonWrapper() {\r\n            if (window.location.pathname.includes(\'customer-service\') &&\r\n                (window.location.pathname.includes(\'en_us\') || window.location.pathname.includes(\'es_us\'))) {\r\n                var newItem = document.createElement("div");\r\n                newItem.id = \'svgButtons\';\r\n\r\n                // Up svg\r\n                const iconSvgUp = document.createElementNS(\'http://www.w3.org/2000/svg\', \'svg\');\r\n                const iconPathUp = document.createElementNS(\r\n                    \'http://www.w3.org/2000/svg\',\r\n                    \'path\'\r\n                );\r\n\r\n                iconSvgUp.setAttribute(\'fill\', \'#222222\');\r\n                iconSvgUp.setAttribute(\'viewBox\', \'4 2 8 8\');\r\n                iconSvgUp.setAttribute(\'width\', 16);\r\n                iconSvgUp.setAttribute(\'height\', 16);\r\n                iconSvgUp.setAttribute(\'title\', \'Expand Cookie banner\');\r\n                iconPathUp.setAttribute(\r\n                    \'d\',\r\n                    \'M4,14.3368542 L4,6.33685425 L5,6.33685425 L5,13.3368542 L12,13.3368542 L12,14.3368542 L4,14.3368542 Z\'\r\n                );\r\n\r\n                iconPathUp.setAttribute(\r\n                    \'transform\', \'translate(8.000000, 10.336854) scale(1, -1) rotate(-45.000000) translate(-8.000000, -10.336854)\');\r\n                iconSvgUp.appendChild(iconPathUp);\r\n                iconSvgUp.addEventListener(\'click\', () => handleClick(\'Up\'));\r\n                newItem.appendChild(iconSvgUp);\r\n                iconSvgUp.style.float = \'right\';\r\n\r\n                // Down svg\r\n                const iconSvgDown = document.createElementNS(\'http://www.w3.org/2000/svg\', \'svg\');\r\n                const iconPathDown = document.createElementNS(\r\n                    \'http://www.w3.org/2000/svg\',\r\n                    \'path\'\r\n                );\r\n\r\n                iconSvgDown.setAttribute(\'fill\', \'#222222\');\r\n                iconSvgDown.setAttribute(\'viewBox\', \'4 2 8 8\');\r\n                iconSvgDown.setAttribute(\'width\', 16);\r\n                iconSvgDown.setAttribute(\'height\', 16);\r\n                iconSvgDown.setAttribute(\'title\', \'Collapse Cookie banner\');\r\n                iconPathDown.setAttribute(\r\n                    \'d\',\r\n                    \'M4,9.65685425 L4,1.65685425 L5,1.65685425 L5,8.65685425 L12,8.65685425 L12,9.65685425 L4,9.65685425 Z\'\r\n                );\r\n\r\n                iconPathDown.setAttribute(\r\n                    \'transform\', \'translate(8.000000, 5.656854) rotate(-45.000000) translate(-8.000000, -5.656854)\');\r\n                iconSvgDown.appendChild(iconPathDown);\r\n             ...

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
#olhei no html e vi onde os produtos estavam, no caso era na parte:
# <ul class="products-listing small">...</ul>

products = soup.find('ul', class_='products-listing small')
products

#o find só retorna o primeiro elemento, o find_all retorna uma lista com tudo; como só tem uma ul da para usar find
# Out:
# <ul class="products-listing small">
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256001" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDFfZW5fdXM7MTAyNDI1NjAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs0NDs','1024256001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256001.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/77/b5/77b566ce3845791ecb47a6252b6c1e16fd93ea68.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/28/55/2855b986c1b682dcbf559fc1facf6ebc87a056e8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/28/55/2855b986c1b682dcbf559fc1facf6ebc87a056e8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256001|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256001.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="8">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159001" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDFfZW5fdXM7MDk4NTE1OTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs0NDs','0985159001');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159001.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/28/f0/28f0649eb24faedfb7baf756d9cc7b86f31e37de.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/28/c6/28c6fee2e6b364c8a9adafb534eb286135403daf.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/28/c6/28c6fee2e6b364c8a9adafb534eb286135403daf.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159001|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159001.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159006.html" style="background-color: #2F323B" title="Dark denim blue">
# 				Dark denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0875105024" data-brand="H&amp;M" data-category="men_jeans_relaxed" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0875105024'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg3NTEwNV9ncm91cF8wMjRfZW5fdXM7MDg3NTEwNTAyNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs0NDs','0875105024');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0875105024.html" title="Relaxed Jeans">
# <img alt="Relaxed JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/8b/6f/8b6f3e1f0ca6fbd57492d96b907b32e638455f3f.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Relaxed Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/69/34/69349506e84007d3a5dcf571bc103d8ed3de0fb6.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/69/34/69349506e84007d3a5dcf571bc103d8ed3de0fb6.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0875105024|Relaxed Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0875105024.html">Relaxed Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105024.html" style="background-color: #798DB2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105016.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105017.html" style="background-color: #54586D" title="Dark denim blue">
# 				Dark denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0875105018.html" style="background-color: #ADBAD1" title="Pale denim blue">
# 				Pale denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256002" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDJfZW5fdXM7MTAyNDI1NjAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs0NDs','1024256002');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256002.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/da/ba/dabaf3f73477f46b068e2e02033aa0222206ef7f.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/17/f1/17f1bb91c09c459b1b0c6e0558576dc6b2f548c0.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/17/f1/17f1bb91c09c459b1b0c6e0558576dc6b2f548c0.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256002|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024256002.html">Slim Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="8">
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256002.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256003.html" style="background-color: #6089C2" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1024256004.html" style="background-color: #7187BC" title="Denim blue">
# 				Denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1004199004" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDRfZW5fdXM7MTAwNDE5OTAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs0NDs','1004199004');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1004199004.html" title="Skinny Cropped Jeans">
# <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/ce/23/ce237bac8d72f49453501ff497b4d4a51128eb13.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/9a/34/9a340bcdc14bf3e8290cb46be23163cfc8c908b8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199004|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1004199004.html">Skinny Cropped Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 29.99</span>
# </strong><ul class="list-swatches" data-swatches-total="5">
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199004.html" style="background-color: #FFFFFF" title="White">
# 				White</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.1004199003.html" style="background-color: #79829D" title="Denim blue">
# 				Denim blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="0985159007" data-brand="H&amp;M" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159007'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDdfZW5fdXM7MDk4NTE1OTAwN19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs0NDs','0985159007');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.0985159007.html" title="Skinny Jeans">
# <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/ce/7e/ce7e4bb772917a1ae43e8b8b9dc0bdb6afbf5d9d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/51/a8/51a81a075021df32fe1b4509ca011e7277598cfb.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159007|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.0985159007.html">Skinny Jeans</a>
# </h3><strong class="item-price">
# <span class="price regular">$ 19.99</span>
# </strong><ul class="list-swatches" data-swatches-total="6">
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159007.html" style="background-color: #79829D" title="Denim blue">
# 				Denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
# 				Black</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
# 				Light denim blue</a></li>
# <li class="item"><a class="swatch" href="/en_us/productpage.0985159005.html" style="background-color: #4C5164" title="Dark blue">
# 				Dark blue</a></li>
# </ul></div></article></li>
# <li class="product-item">
# <article class="hm-product-item" data-articlecode="1024256003" data-brand="H&amp;M" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" data-style-with-articlecodes="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1024256003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAyNDI1Nl9ncm91cF8wMDNfZW5fdXM7MTAyNDI1NjAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs0NDs','1024256003');">
# <div class="image-container">
# <a class="item-link" href="/en_us/productpage.1024256003.html" title="Slim Jeans">
# <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e3/e8/e3e81b8bc860bd9ba65e2940d0a7c9635d42cc66.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/19/87/19876165367c49d17f3b8a9f51402fde689f3576.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
# <div class="item-buttons">
# <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1024256003|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
# 				SAVE AS FAVORITE</button>
# </div></a>
# </div><div class="item-details">
# <div class="marketing-marker marker-environment" style="">
# 		Conscious choice  </div>
# <h3 class="item-heading">
# <a class="link" href="/en_us/productpage.1024
html" style="background-color: #494A4F" title="Dark gray">
#  				Dark gray</a></li>
#  </ul><div class="new-product">New Arrival</div>
#  </div></article>]

# %%
print(f'Tem {len(products_list)} produtos')
# Out:
# Tem 36 produtos

# %%
#data-article code é o ID do produto
products_list[1].get('data-articlecode')
# Out:
# '0985159001'

# %% [markdown]
# ### product id

# %%
#product id
product_id = [p.get('data-articlecode') for p in products_list]
product_id
# Out:
# ['1024256001',
#  '0985159001',
#  '0875105024',
#  '1024256002',
#  '1004199004',
#  '0985159007',
#  '1024256003',
#  '0690449036',
#  '1024256005',
#  '0690449022',
#  '0985159008',
#  '0971061002',
#  '0690449051',
#  '1024256007',
#  '0985159005',
#  '0690449043',
#  '0875105018',
#  '1008549001',
#  '0690449056',
#  '1024256004',
#  '0971061005',
#  '0971061004',
#  '1008549006',
#  '1008110001',
#  '0938875007',
#  '0985159006',
#  '1004199001',
#  '0938875013',
#  '1004199002',
#  '1008549002',
#  '1008110002',
#  '0971061006',
#  '1074475001',
#  '1024256008',
#  '1008549003',
#  '1013317012']

# %% [markdown]
# ### product category

# %%
#product category
product_category = [p.get('data-category') for p in products_list]
product_category
# Out:
# ['men_jeans_slim',
#  'men_jeans_skinny',
#  'men_jeans_relaxed',
#  'men_jeans_slim',
#  'men_jeans_skinny',
#  'men_jeans_skinny',
#  'men_jeans_slim',
#  'men_jeans_ripped',
#  'men_jeans_slim',
#  'men_jeans_ripped',
#  'men_jeans_skinny',
#  'men_jeans_slim',
#  'men_jeans_ripped',
#  'men_jeans_slim',
#  'men_jeans_skinny',
#  'men_jeans_ripped',
#  'men_jeans_relaxed',
#  'men_jeans_regular',
#  'men_jeans_ripped',
#  'men_jeans_slim',
#  'men_jeans_slim',
#  'men_jeans_slim',
#  'men_jeans_regular',
#  'men_jeans_slim',
#  'men_jeans_slim',
#  'men_jeans_skinny',
#  'men_jeans_skinny',
#  'men_jeans_slim',
#  'men_jeans_skinny',
#  'men_jeans_regular',
#  'men_jeans_slim',
#  'men_jeans_slim',
#  'men_jeans_loose',
#  'men_jeans_slim',
#  'men_jeans_regular',
#  'men_jeans_joggers']

# %% [markdown]
# ### product name

# %%
#product name
product_list = products.find_all('a', class_='link')

product_list[0].get_text()
# Out:
# 'Slim Jeans'

# %%
product_name = [p.get_text() for p in product_list]
product_name
# Out:
# ['Slim Jeans',
#  'Skinny Jeans',
#  'Relaxed Jeans',
#  'Slim Jeans',
#  'Skinny Cropped Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Slim Tapered Cropped Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Skinny Jeans',
#  'Skinny Jeans',
#  'Relaxed Jeans',
#  'Regular Jeans',
#  'Skinny Jeans',
#  'Slim Jeans',
#  'Slim Tapered Cropped Jeans',
#  'Slim Tapered Cropped Jeans',
#  'Regular Jeans',
#  'Freefit® Slim Jeans',
#  'Slim Tapered Jeans',
#  'Skinny Jeans',
#  'Skinny Cropped Jeans',
#  'Slim Tapered Jeans',
#  'Skinny Cropped Jeans',
#  'Regular Jeans',
#  'Freefit® Slim Jeans',
#  'Slim Tapered Cropped Jeans',
#  'Loose Jeans',
#  'Slim Jeans',
#  'Regular Jeans',
#  'Hybrid Regular Tapered Joggers']

# %% [markdown]
# ### product price

# %%
#product price
# <span class="price regular">$ 19.99</span>

product_list = products.find_all('span',class_='price regular')
product_price = [p.get_text() for p in product_list]
product_price
# Out:
# ['$ 19.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 39.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 39.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 49.99',
#  '$ 39.99',
#  '$ 19.99',
#  '$ 29.99',
#  '$ 39.99',
#  '$ 29.99',
#  '$ 19.99',
#  '$ 49.99',
#  '$ 29.99',
#  '$ 39.99',
#  '$ 19.99',
#  '$ 19.99',
#  '$ 44.99']

# %% [markdown]
# ### criação do dataframe

# %%
data = pd.DataFrame( [product_id, product_category, product_name,product_price]).T

data.columns = ['product_id', 'product_category', 'product_name','product_price']

data.head()
# Out:
#    product_id   product_category          product_name product_price
# 0  1024256001     men_jeans_slim            Slim Jeans       $ 19.99
# 1  0985159001   men_jeans_skinny          Skinny Jeans       $ 19.99
# 2  0875105024  men_jeans_relaxed         Relaxed Jeans       $ 29.99
# 3  1024256002     men_jeans_slim            Slim Jeans       $ 19.99
# 4  1004199004   men_jeans_skinny  Skinny Cropped Jeans       $ 29.99

# %%
# scrapy datetime
data['scrapy_datetime'] = datetime.now().strftime( '%Y-%m-%d %H:%M:%S' )

# %%
data.head()
# Out:
#    product_id   product_category          product_name product_price  \
# 0  1024256001     men_jeans_slim            Slim Jeans       $ 19.99
# 1  0985159001   men_jeans_skinny          Skinny Jeans       $ 19.99
# 2  0875105024  men_jeans_relaxed         Relaxed Jeans       $ 29.99
# 3  1024256002     men_jeans_slim            Slim Jeans       $ 19.99
# 4  1004199004   men_jeans_skinny  Skinny Cropped Jeans       $ 29.99
#
#        scrapy_datetime
# 0  2022-06-21 16:26:02
# 1  2022-06-21 16:26:02
# 2  2022-06-21 16:26:02
# 3  2022-06-21 16:26:02
# 4  2022-06-21 16:26:02

# %% [markdown]
# # aula 25

# %%
url = 'https://www2.hm.com/en_us/men/products/jeans.html'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

#requisição para mostrar para a API que quem está fazendo a requisição dos dados é um 
#browser e não um código python

page = requests.get (url, headers = headers)

# %%
#para pegar o html da página
#page.text

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %% [markdown]
# ### Paginação

# %% [markdown]
# - Nas páginas html são feitas paginações, que consiste em dividir os produtos em páginas para não sobrecarregar a API. Normalmente na url tem os parâmetros e é possível ver como funciona a divisão na página (offset=0&page-size=72)
#     - offset é o valor que começa a mostrar o produto
#     - page-size é até qual produto é mostrando na página

# %%
#paginação: para saber quantos produtos tem por página 
#pela inspeção (inspecionar) na página vi que está na tag h2 e na class 'load-more-heading'
soup.find_all('h2' , class_='load-more-heading')
# Out:
# [<h2 class="load-more-heading" data-items-shown="36" data-total="84">SHOWING 36 of 84 Items</h2>]

# %%
total_item = soup.find_all('h2' , class_='load-more-heading')[0].get('data-total')
total_item
# Out:
# '84'

# %%
#transformar em inteiro
int(total_item)
# Out:
# 84

# %%
#no caso pelo site vimos que tem 36 produtos por página, então para saber quantas páginas vamos precisar:
page_number = np.round(int(total_item)/36)
page_number
# Out:
# 2.0

# %%
#montando a url
#em uma url depois do ? fica os parâmetros 

url02 = url + '?page-size' + str(int(page_number*36))
url02
# Out:
# 'https://www2.hm.com/en_us/men/products/jeans.html?page-size72'

# %% [markdown]
# # aula 26 e 27

# %% [markdown]
# ### pegando as informações de um produto específico

# %%
import requests
import pandas as pd
from datetime import datetime
from bs4 import BeautifulSoup
import numpy as np

# %%
#primeiro faz o webscraping de um produto sozinho, se funcionar faz com todos os outros

url = 'https://www2.hm.com/en_us/productpage.0636207010.html'

#para fazer requisição na API para puxar os dados html
#headers é um dicionário que vai dizer pra API da H&M que quem está fazendo a requisição
#é um browser e não um código python; é padrão

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
           
page = requests.get(url, headers=headers)

page.text

soup = BeautifulSoup(page.text, 'html.parser')

# %% [markdown]
# ### color name

# %%
#ir na página, inspecionar e procurar onde na html está a informação de cor
soup.find_all('a',class_='filter-option miniature')[0].get('data-color')
# Out:
# 'Dark denim blue'

# %%
product_list= soup.find_all('a',class_='filter-option miniature')
product_list
# Out:
# [<a aria-checked="false" class="filter-option miniature" data-articlecode="0636207001" data-color="Dark denim blue" data-sizes="" href="/en_us/productpage.0636207001.html" id="filter-colour-0636207001" role="radio" title="Dark denim blue">
#  <noscript data-alt="Dark denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F36%2F49%2F3649b9506787743b7d4b0e5f8014d13946bf3632.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Dark denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F36%2F49%2F3649b9506787743b7d4b0e5f8014d13946bf3632.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="0636207002" data-color="Dark gray denim" data-sizes="" href="/en_us/productpage.0636207002.html" id="filter-colour-0636207002" role="radio" title="Dark gray denim">
#  <noscript data-alt="Dark gray denim" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F52%2F6a%2F526afc88f7f64c0f606582203bcc1d9952921e71.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Dark gray denim" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F52%2F6a%2F526afc88f7f64c0f606582203bcc1d9952921e71.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="0636207004" data-color="Denim blue" data-sizes="" href="/en_us/productpage.0636207004.html" id="filter-colour-0636207004" role="radio" title="Denim blue">
#  <noscript data-alt="Denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fb8%2Fb9%2Fb8b9f1499f5dc76532a651d8813e64c3025aca6e.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fb8%2Fb9%2Fb8b9f1499f5dc76532a651d8813e64c3025aca6e.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="0636207005" data-color="Gray" data-sizes="" href="/en_us/productpage.0636207005.html" id="filter-colour-0636207005" role="radio" title="Gray">
#  <noscript data-alt="Gray" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fd9%2F81%2Fd9815610e9d790e5f050a394518a1f7aeadef7b6.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Gray" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fd9%2F81%2Fd9815610e9d790e5f050a394518a1f7aeadef7b6.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="0636207006" data-color="Black" data-sizes="" href="/en_us/productpage.0636207006.html" id="filter-colour-0636207006" role="radio" title="Black">
#  <noscript data-alt="Black" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fcb%2F05%2Fcb05c1b698d7d23cea43a5c8cf49629fa6b2c98c.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Black" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fcb%2F05%2Fcb05c1b698d7d23cea43a5c8cf49629fa6b2c98c.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="0636207011" data-color="Midnight blue" data-sizes="" href="/en_us/productpage.0636207011.html" id="filter-colour-0636207011" role="radio" title="Midnight blue">
#  <noscript data-alt="Midnight blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F81%2F65%2F8165668289603f5ecc3b91f56632228c36d3c315.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Midnight blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F81%2F65%2F8165668289603f5ecc3b91f56632228c36d3c315.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="0636207014" data-color="Dark gray" data-sizes="" href="/en_us/productpage.0636207014.html" id="filter-colour-0636207014" role="radio" title="Dark gray">
#  <noscript data-alt="Dark gray" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F54%2Fec%2F54ec204c34a18e8f9f13ceb92e22bf226ba7761f.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Dark gray" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F54%2Fec%2F54ec204c34a18e8f9f13ceb92e22bf226ba7761f.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B1%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="0636207015" data-color="Denim blue" data-sizes="" href="/en_us/productpage.0636207015.html" id="filter-colour-0636207015" role="radio" title="Denim blue">
#  <noscript data-alt="Denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F34%2F9f%2F349f53a3217cc7bdad93238340843f8d5fb80b49.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F34%2F9f%2F349f53a3217cc7bdad93238340843f8d5fb80b49.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="0636207017" data-color="White" data-sizes="" href="/en_us/productpage.0636207017.html" id="filter-colour-0636207017" role="radio" title="White">
#  <noscript data-alt="White" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F2c%2Fe3%2F2ce3a99faa279d2547c5a64e82c1ab177a41bfb5.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="White" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2F2c%2Fe3%2F2ce3a99faa279d2547c5a64e82c1ab177a41bfb5.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>,
#  <a aria-checked="false" class="filter-option miniature" data-articlecode="0636207019" data-color="Pale denim blue" data-sizes="" href="/en_us/productpage.0636207019.html" id="filter-colour-0636207019" role="radio" title="Pale denim blue">
#  <noscript data-alt="Pale denim blue" data-src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fd8%2Fb0%2Fd8b07b56b8dc643f5f1849d88041e222d1c718bb.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]">
#  <img alt="Pale denim blue" src="//lp2.hm.com/hmgoepprod?set=quality%5B79%5D%2Csource%5B%2Fd8%2Fb0%2Fd8b07b56b8dc643f5f1849d88041e222d1c718bb.jpg%5D%2Corigin%5Bdam%5D%2Ccategory%5Bmen_jeans_slim%5D%2Ctype%5BDESCRIPTIVESTILLLIFE%5D%2Cres%5Bm%5D%2Chmver%5B2%5D&amp;call=url[file:/product/miniature]"/>
#  </noscript>
#  <span></span>
#  </a>]

# %%
#percorrendo todas as cores do produto
color_name = [p.get('data-color') for p in product_list]
color_name
# Out:
# ['Dark denim blue',
#  'Dark gray denim',
#  'Denim blue',
#  'Gray',
#  'Black',
#  'Midnight blue',
#  'Dark gray',
#  'Denim blue',
#  'White',
#  'Pale denim blue']

# %% [markdown]
# ### product id

# %%
product_id = [p.get('data-articlecode') for p in product_list]
product_id
# Out:
# ['0636207001',
#  '0636207002',
#  '0636207004',
#  '0636207005',
#  '0636207006',
#  '0636207011',
#  '0636207014',
#  '0636207015',
#  '0636207017',
#  '0636207019']

# %%
#criando o df
df_color = pd.DataFrame([product_id, color_name]).T
df_color.columns = ['product_id','product_color']
df_color
# Out:
#    product_id    product_color
# 0  0636207001  Dark denim blue
# 1  0636207002  Dark gray denim
# 2  0636207004       Denim blue
# 3  0636207005             Gray
# 4  0636207006            Black
# 5  0636207011    Midnight blue
# 6  0636207014        Dark gray
# 7  0636207015       Denim blue
# 8  0636207017            White
# 9  0636207019  Pale denim blue

# %%
#criando o style id + color id
df_color['style_id'] = df_color['product_id'].apply(lambda x: x[:-3])
df_color['color_id'] = df_color['product_id'].apply(lambda x: x[-3:])

# %%
df_color
# Out:
#    product_id    product_color style_id color_id
# 0  0636207001  Dark denim blue  0636207      001
# 1  0636207002  Dark gray denim  0636207      002
# 2  0636207004       Denim blue  0636207      004
# 3  0636207005             Gray  0636207      005
# 4  0636207006            Black  0636207      006
# 5  0636207011    Midnight blue  0636207      011
# 6  0636207014        Dark gray  0636207      014
# 7  0636207015       Denim blue  0636207      015
# 8  0636207017            White  0636207      017
# 9  0636207019  Pale denim blue  0636207      019

# %% [markdown]
# Vai na html, procura qual estrutura da html seu dado está armazenado, vê se tem algum nome de estrutura (seja classe, seja div, seja ID etc) que é única  ou se repete para todos os pontos onde os dados estão armazenados e vamos usar isso para poder extrair aquele estrutura html.
# Depois que extrair a estrutura html a gente extrai o dado de dentro da estrutura.

# %% [markdown]
# ### compositon

# %%
soup.find_all('div', class_='details-attributes-list-item')
# Out:
# [<div class="details-attributes-list-item">
#  <dt class="details-headline">messages.garmentLength</dt>
#  <dd class="details-list-item">Long</dd>
#  </div>,
#  <div class="details-attributes-list-item">
#  <dt class="details-headline">messages.waistRise</dt>
#  <dd class="details-list-item">Regular waist</dd>
#  </div>,
#  <div class="details-attributes-list-item">
#  <dt class="details-headline">Fit</dt>
#  <dd class="details-list-item">Slim fit</dd>
#  </div>,
#  <div class="details-attributes-list-item">
#  <dt class="details-headline">Composition</dt>
#  <dd class="details-list-item">Cotton 88%, Polyester 10%, Spandex 2%</dd>
#  <dd class="details-list-item">Pocket lining: Cotton 100%</dd>
#  </div>,
#  <div class="details-attributes-list-item">
#  <dt class="details-headline">Care instructions</dt>
#  <dd class="details-list-item">Only non-chlorine bleach when needed</dd>
#  <dd class="details-list-item">Medium iron</dd>
#  <dd class="details-list-item">Machine wash cool</dd>
#  <dd class="details-list-item">Wash with like colors</dd>
#  <dd class="details-list-item">Line dry</dd>
#  <dd class="details-list-item">Can be dry cleaned</dd>
#  </div>,
#  <div class="details-attributes-list-item">
#  <dt class="details-headline">Material</dt>
#  <dd class="details-list-item">Denim</dd>
#  </div>,
#  <div class="details-attributes-list-item">
#  <dt class="details-headline">Description</dt>
#  <dd class="details-list-item">Light denim blue</dd>
#  <dd class="details-list-item">Solid-color</dd>
#  </div>,
#  <div class="details-attributes-list-item">
#  <dt class="details-headline">Imported</dt>
#  <dd class="details-list-item">Yes</dd>
#  </div>,
#  <div class="details-attributes-list-item">
#  <dt class="details-headline">Concept</dt>
#  <dd class="details-list-item">DENIM</dd>
#  </div>,
#  <div class="details-attributes-list-item">
#  <dt class="details-headline">Art. No.</dt>
#  <dd class="details-list-item">0636207010</dd>
#  </div>]

# %%
#parte fit e slim 
#get_text retorna os elementos entre as estruturas html

soup.find_all('div', class_='details-attributes-list-item')[2].get_text()
# Out:
# '\nFit\nSlim fit\n'

# %%
#quebra do texto em listas segundo um parâmetro, no caso '\n'
soup.find_all( 'div',class_='details-attributes-list-item' )[2].get_text().split('\n')
# Out:
# ['', 'Fit', 'Slim fit', '']

# %%
#filtra os valores vazios
list(filter(None,soup.find_all( 'div',class_='details-attributes-list-item' )[2].get_text().split('\n')))
# Out:
# ['Fit', 'Slim fit']

# %%
#composição

product_composition_list = soup.find_all('div', class_='details-attributes-list-item')

product_composition_full = [list(filter(None,p.get_text().split('\n'))) for p in product_composition_list]

#rename dataframe
df_aux_full = pd.DataFrame(product_composition_full).T
df_aux_full.columns = df_aux_full.iloc[0]

#delete first row
df_aux_full = df_aux_full.iloc[1:].fillna(method='ffill')

#Para arrumar o df que tem informações a mais que eu preciso
ex = pd.DataFrame(columns=['Fit','Composition','Art. No.'])
df_composition = pd.merge(ex, df_aux_full[['Fit','Composition','Art. No.']], how = 'right', on=['Fit','Composition','Art. No.'])
df_composition = df_composition.drop_duplicates()

# %%
#gerando style id + color id
df_composition['style_id'] = df_composition['Art. No.'].apply(lambda x: x[:-3])
df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])
df_composition
# Out:
#         Fit                            Composition    Art. No. style_id  \
# 0  Slim fit  Cotton 88%, Polyester 10%, Spandex 2%  0636207010  0636207
# 1  Slim fit             Pocket lining: Cotton 100%  0636207010  0636207
#
#   color_id
# 0      010
# 1      010

# %%
#juntando data color + composition
data_sku = pd.merge(df_color,df_composition[['style_id','Fit','Composition']], how='left', on='style_id')
data_sku
# Out:
#     product_id    product_color style_id color_id       Fit  \
# 0   0636207001  Dark denim blue  0636207      001  Slim fit
# 1   0636207001  Dark denim blue  0636207      001  Slim fit
# 2   0636207002  Dark gray denim  0636207      002  Slim fit
# 3   0636207002  Dark gray denim  0636207      002  Slim fit
# 4   0636207004       Denim blue  0636207      004  Slim fit
# 5   0636207004       Denim blue  0636207      004  Slim fit
# 6   0636207005             Gray  0636207      005  Slim fit
# 7   0636207005             Gray  0636207      005  Slim fit
# 8   0636207006            Black  0636207      006  Slim fit
# 9   0636207006            Black  0636207      006  Slim fit
# 10  0636207011    Midnight blue  0636207      011  Slim fit
# 11  0636207011    Midnight blue  0636207      011  Slim fit
# 12  0636207014        Dark gray  0636207      014  Slim fit
# 13  0636207014        Dark gray  0636207      014  Slim fit
# 14  0636207015       Denim blue  0636207      015  Slim fit
# 15  0636207015       Denim blue  0636207      015  Slim fit
# 16  0636207017            White  0636207      017  Slim fit
# 17  0636207017            White  0636207      017  Slim fit
# 18  0636207019  Pale denim blue  0636207      019  Slim fit
# 19  0636207019  Pale denim blue  0636207      019  Slim fit
#
#                               Composition
# 0   Cotton 88%, Polyester 10%, Spandex 2%
# 1              Pocket lining: Cotton 100%
# 2   Cotton 88%, Polyester 10%, Spandex 2%
# 3              Pocket lining: Cotton 100%
# 4   Cotton 88%, Polyester 10%, Spandex 2%
# 5              Pocket lining: Cotton 100%
# 6   Cotton 88%, Polyester 10%, Spandex 2%
# 7              Pocket lining: Cotton 100%
# 8   Cotton 88%, Polyester 10%, Spandex 2%
# 9              Pocket lining: Cotton 100%
# 10  Cotton 88%, Polyester 10%, Spandex 2%
# 11             Pocket lining: Cotton 100%
# 12  Cotton 88%, Polyester 10%, Spandex 2%
# 13             Pocket lining: Cotton 100%
# 14  Cotton 88%, Polyester 10%, Spandex 2%
# 15             Pocket lining: Cotton 100%
# 16  Cotton 88%, Polyester 10%, Spandex 2%
# 17             Pocket lining: Cotton 100%
# 18  Cotton 88%, Polyester 10%, Spandex 2%
# 19             Pocket lining: Cotton 100%

# %% [markdown]
# ### Resultado para um produto:

# %% [markdown]
# # One product

# %%
#API requests
#primeiro faz o webscraping de um produto sozinho, se funcionar faz com todos os outros
url = 'https://www2.hm.com/en_us/productpage.0636207010.html'

#para fazer requisição na API para puxar os dados html
#headers é um dicionário que vai dizer pra API da H&M que quem está fazendo a requisição
#é um browser e não um código python; é padrão

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
           
page = requests.get(url, headers=headers)

page.text

#BeautifulSoup objects
soup = BeautifulSoup(page.text, 'html.parser')


########################### color name ###################################
product_list= soup.find_all('a',class_='filter-option miniature')

#percorrendo todas as cores do produto
color_name = [p.get('data-color') for p in product_list]

#procuct id
product_id = [p.get('data-articlecode') for p in product_list]

#criando o df
df_color = pd.DataFrame([product_id, color_name]).T
df_color.columns = ['product_id','color_name']

#criando o style id + color id
df_color['style_id'] = df_color['product_id'].apply(lambda x: x[:-3])
df_color['color_id'] = df_color['product_id'].apply(lambda x: x[-3:])

########################### composition ###################################
product_composition_list = soup.find_all('div', class_='details-attributes-list-item')

product_composition_full = [list(filter(None,p.get_text().split('\n'))) for p in product_composition_list]

#rename dataframe
df_aux_full = pd.DataFrame(product_composition_full).T
df_aux_full.columns = df_aux_full.iloc[0]

#delete first row
df_aux_full = df_aux_full.iloc[1:].fillna(method='ffill')

#Para arrumar o df que tem informações a mais que eu preciso
ex = pd.DataFrame(columns=['Fit','Composition','Art. No.'])
df_composition = pd.merge(ex, df_aux_full[['Fit','Composition','Art. No.']], how = 'right', on=['Fit','Composition','Art. No.'])
df_composition = df_composition.drop_duplicates()

#gerando style id + color id
df_composition['style_id'] = df_composition['Art. No.'].apply(lambda x: x[:-3])
df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])

#juntando data color + composition
data_sku = pd.merge(df_color,df_composition[['style_id','Fit','Composition']], how='left', on='style_id')
data_sku
# Out:
#     product_id       color_name style_id color_id       Fit  \
# 0   0636207001  Dark denim blue  0636207      001  Slim fit
# 1   0636207001  Dark denim blue  0636207      001  Slim fit
# 2   0636207002  Dark gray denim  0636207      002  Slim fit
# 3   0636207002  Dark gray denim  0636207      002  Slim fit
# 4   0636207004       Denim blue  0636207      004  Slim fit
# 5   0636207004       Denim blue  0636207      004  Slim fit
# 6   0636207005             Gray  0636207      005  Slim fit
# 7   0636207005             Gray  0636207      005  Slim fit
# 8   0636207006            Black  0636207      006  Slim fit
# 9   0636207006            Black  0636207      006  Slim fit
# 10  0636207011    Midnight blue  0636207      011  Slim fit
# 11  0636207011    Midnight blue  0636207      011  Slim fit
# 12  0636207014        Dark gray  0636207      014  Slim fit
# 13  0636207014        Dark gray  0636207      014  Slim fit
# 14  0636207015       Denim blue  0636207      015  Slim fit
# 15  0636207015       Denim blue  0636207      015  Slim fit
# 16  0636207017            White  0636207      017  Slim fit
# 17  0636207017            White  0636207      017  Slim fit
# 18  0636207019  Pale denim blue  0636207      019  Slim fit
# 19  0636207019  Pale denim blue  0636207      019  Slim fit
#
#                               Composition
# 0   Cotton 88%, Polyester 10%, Spandex 2%
# 1              Pocket lining: Cotton 100%
# 2   Cotton 88%, Polyester 10%, Spandex 2%
# 3              Pocket lining: Cotton 100%
# 4   Cotton 88%, Polyester 10%, Spandex 2%
# 5              Pocket lining: Cotton 100%
# 6   Cotton 88%, Polyester 10%, Spandex 2%
# 7              Pocket lining: Cotton 100%
# 8   Cotton 88%, Polyester 10%, Spandex 2%
# 9              Pocket lining: Cotton 100%
# 10  Cotton 88%, Polyester 10%, Spandex 2%
# 11             Pocket lining: Cotton 100%
# 12  Cotton 88%, Polyester 10%, Spandex 2%
# 13             Pocket lining: Cotton 100%
# 14  Cotton 88%, Polyester 10%, Spandex 2%
# 15             Pocket lining: Cotton 100%
# 16  Cotton 88%, Polyester 10%, Spandex 2%
# 17             Pocket lining: Cotton 100%
# 18  Cotton 88%, Polyester 10%, Spandex 2%
# 19             Pocket lining: Cotton 100%

# %% [markdown]
# ### Multi Products

# %%
#cada linha é um produto na vitrine
data.head()
# Out:
#    product_id   product_category          product_name product_price  \
# 0  1024256001     men_jeans_slim            Slim Jeans       $ 19.99
# 1  0985159001   men_jeans_skinny          Skinny Jeans       $ 19.99
# 2  0875105024  men_jeans_relaxed         Relaxed Jeans       $ 29.99
# 3  1024256002     men_jeans_slim            Slim Jeans       $ 19.99
# 4  1004199004   men_jeans_skinny  Skinny Cropped Jeans       $ 29.99
#
#        scrapy_datetime
# 0  2022-06-21 16:26:02
# 1  2022-06-21 16:26:02
# 2  2022-06-21 16:26:02
# 3  2022-06-21 16:26:02
# 4  2022-06-21 16:26:02

# %%
#gerando todas as urls

for i in range(len(data)):
    #API requests
    url = 'https://www2.hm.com/en_us/productpage.' + data.loc[i,'product_id'] + '.html'
    print(url)
# Out:
# https://www2.hm.com/en_us/productpage.0985159001.html
# https://www2.hm.com/en_us/productpage.1024256001.html
# https://www2.hm.com/en_us/productpage.0875105024.html
# https://www2.hm.com/en_us/productpage.0690449056.html
# https://www2.hm.com/en_us/productpage.1004199004.html
# https://www2.hm.com/en_us/productpage.1024256002.html
# https://www2.hm.com/en_us/productpage.0985159007.html
# https://www2.hm.com/en_us/productpage.1024256003.html
# https://www2.hm.com/en_us/productpage.1024256004.html
# https://www2.hm.com/en_us/productpage.1024256005.html
# https://www2.hm.com/en_us/productpage.1008110001.html
# https://www2.hm.com/en_us/productpage.0971061002.html
# https://www2.hm.com/en_us/productpage.0690449036.html
# https://www2.hm.com/en_us/productpage.0971061005.html
# https://www2.hm.com/en_us/productpage.0690449051.html
# https://www2.hm.com/en_us/productpage.0690449022.html
# https://www2.hm.com/en_us/productpage.1008549001.html
# https://www2.hm.com/en_us/productpage.1024256007.html
# https://www2.hm.com/en_us/productpage.0985159008.html
# https://www2.hm.com/en_us/productpage.1008549006.html
# https://www2.hm.com/en_us/productpage.0971061006.html
# https://www2.hm.com/en_us/productpage.0971061004.html
# https://www2.hm.com/en_us/productpage.0985159006.html
# https://www2.hm.com/en_us/productpage.1004199002.html
# https://www2.hm.com/en_us/productpage.1008110002.html
# https://www2.hm.com/en_us/productpage.0690449043.html
# https://www2.hm.com/en_us/productpage.1004199001.html
# https://www2.hm.com/en_us/productpage.1008549002.html
# https://www2.hm.com/en_us/productpage.0985159005.html
# https://www2.hm.com/en_us/productpage.0875105018.html
# https://www2.hm.com/en_us/productpage.1074475001.html
# https://www2.hm.com/en_us/productpage.1008549003.html
# https://www2.hm.com/en_us/productpage.1024256008.html
# https://www2.hm.com/en_us/productpage.1008549004.html
# https://www2.hm.com/en_us/productpage.1013317012.html
# https://www2.hm.com/en_us/productpage.1008549008.html

# %%
#A diferença principal é que para multiplos produtos a url muda

#criando um df vazio para juntar todos os produtos nele
df_details = pd.DataFrame()

#lista vazia para colocar todos os nomes das colunas para que o df seja padronizado, se algum produto
#não tiver alguma coluna vai ficar vazio
aux = []

cols = ['Art. No.', 'Composition', 'Fit', 'color_id', 'style_id']
df_pattern = pd.DataFrame(columns=cols)

#parametros
#headers é um dicionário que vai dizer pra API da H&M que quem está fazendo a requisição
#é um browser e não um código python; é padrão
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
  
#gerando todas as urls
for i in range(len(data)):
    #API requests
    url = 'https://www2.hm.com/en_us/productpage.' + data.loc[i,'product_id'] + '.html'
    #print(url)
    
    #para fazer requisição na API para puxar os dados html       
    page = requests.get(url, headers=headers)

    #BeautifulSoup objects
    soup = BeautifulSoup(page.text, 'html.parser')

    ########################### color name ###################################
    product_list= soup.find_all('a',class_='filter-option miniature')

    #percorrendo todas as cores do produto
    color_name = [p.get('data-color') for p in product_list]

    #procuct id
    product_id = [p.get('data-articlecode') for p in product_list]

    #criando o df
    df_color = pd.DataFrame([product_id, color_name]).T
    df_color.columns = ['product_id','color_name']

    #criando o style id + color id
    df_color['style_id'] = df_color['product_id'].apply(lambda x: x[:-3])
    df_color['color_id'] = df_color['product_id'].apply(lambda x: x[-3:])

    ########################### composition ###################################
    product_composition_list = soup.find_all('div', class_='details-attributes-list-item')

    product_composition_full = [list(filter(None,p.get_text().split('\n'))) for p in product_composition_list]

    #rename dataframe
    df_aux_full = pd.DataFrame(product_composition_full).T
    df_aux_full.columns = df_aux_full.iloc[0]

    #delete first row
    df_aux_full = df_aux_full.iloc[1:].fillna(method='ffill')
    
    #garantia que tenha a mesma quantidade de colunas
    df_composition = pd.concat( [df_pattern, df_composition], axis=0 )

    #Para arrumar o df que tem informações a mais que eu preciso
    ex = pd.DataFrame(columns=['Fit','Composition','Art. No.'])
    df_composition = pd.merge(ex, df_aux_full[['Fit','Composition','Art. No.']], how = 'right', on=['Fit','Composition','Art. No.'])
    df_composition = df_composition.drop_duplicates()

    #gerando style id + color id
    df_composition['style_id'] = df_composition['Art. No.'].apply(lambda x: x[:-3])
    df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])

    #lista vazia para colocar todos os nomes das colunas para que o df seja padronizado, se algum produto
    #não tiver alguma coluna vai ficar vazio
    aux = aux + df_composition.columns.tolist()
    
    #juntando data color + composition
    data_sku = pd.merge(df_color,df_composition[['style_id', 'Fit','Composition']], how='left', on='style_id')
    
    #juntando todos os dataframes individuais em um único df com todos os produtos
    df_details = pd.concat([df_details, data_sku], axis = 0)
    
# Join Showroom data + details
data['style_id'] = data['product_id'].apply(lambda x: x[:-3])
data['color_id'] = data['product_id'].apply(lambda x: x[-3:])

data_raw = pd.merge(data, df_details[['style_id', 'color_name', 'Fit','Composition']], how='left',on='style_id')

# %%
#set mostra os dados sem duplicação
#usado para saber quais dados tem os produtos
set(aux)
# Out:
# {'Art. No.', 'Composition', 'Fit', 'color_id', 'style_id'}

# %%
df_details.head()
# Out:
#    product_id        color_name style_id color_id       Fit  \
# 0  1024256002  Light denim blue  1024256      002  Slim fit
# 1  1024256002  Light denim blue  1024256      002  Slim fit
# 2  1024256003  Light denim blue  1024256      003  Slim fit
# 3  1024256003  Light denim blue  1024256      003  Slim fit
# 4  1024256004        Denim blue  1024256      004  Slim fit
#
#                                 Composition
# 0             Shell: Cotton 99%, Spandex 1%
# 1  Pocket lining: Polyester 65%, Cotton 35%
# 2             Shell: Cotton 99%, Spandex 1%
# 3  Pocket lining: Polyester 65%, Cotton 35%
# 4             Shell: Cotton 99%, Spandex 1%

# %%
#exportando para csv
data_raw.to_csv(r'C:\Users\laais\CDS_Python_do_DS_ao_DEV\df_products_hm.csv', index=0)

# %%
data_raw.head()
# Out:
#    product_id product_category product_name product_price  \
# 0  1024256001   men_jeans_slim   Slim Jeans       $ 19.99
# 1  1024256001   men_jeans_slim   Slim Jeans       $ 19.99
# 2  1024256001   men_jeans_slim   Slim Jeans       $ 19.99
# 3  1024256001   men_jeans_slim   Slim Jeans       $ 19.99
# 4  1024256001   men_jeans_slim   Slim Jeans       $ 19.99
#
#        scrapy_datetime style_id color_id        color_name       Fit  \
# 0  2022-06-21 16:26:02  1024256      001  Light denim blue  Slim fit
# 1  2022-06-21 16:26:02  1024256      001  Light denim blue  Slim fit
# 2  2022-06-21 16:26:02  1024256      001  Light denim blue  Slim fit
# 3  2022-06-21 16:26:02  1024256      001  Light denim blue  Slim fit
# 4  2022-06-21 16:26:02  1024256      001        Denim blue  Slim fit
#
#                                 Composition
# 0             Shell: Cotton 99%, Spandex 1%
# 1  Pocket lining: Polyester 65%, Cotton 35%
# 2             Shell: Cotton 99%, Spandex 1%
# 3  Pocket lining: Polyester 65%, Cotton 35%
# 4             Shell: Cotton 99%, Spandex 1%
